# %% [markdown]
# ##### !!! please DO NOT rename this file !!!

# %% [markdown]
# ### 【TaskA】20 skills for Python beginner
# - student id:111524019
# - name：陳品蓁

# %% [markdown]
# ##### 【Q1】Designe a Program to manage customer's money.
# - For example
#  - money = {'Tom' : 30000, 'Mary' : 64000, 'Gary' : 72000, 'Tim' : 500, 'Eva' : 6150}
#
#
# - Please write a program to manage customers' money.
#  - You must use input() and a dictionary to record each customers' money.
#  - You should run and DEMO the function in this JupyterNB.
#  - Write an interactive menu for the user to choose the action, which includes at least the following functions:
#   - 1. Let user create the name and the money for "more than one" customers at once.
#   - 2. List the money of all customers.
#   - 3. User can deposit and withdraw money for customers.
#   - 4. At least one addtional function. e.g. exchange foreign currency, transfer money...
#
#
# - 請幫老師設計一個程式管理客戶的金錢。
#  - 必須使用input()和字典來記錄客戶的金錢。
#  - 需要為使用者編寫一個互動選單，其中至少包括以下功能：
#  - 需要在本頁面一一執行你設計好的功能。
#   - 1. 讓使用者一次創建多個客戶的名字和金錢。
#   - 2. 列出所有客戶的金錢。
#   - 3. 使用者可以為客戶存錢及提款。
#   - 4. 至少一個上面沒提到的額外功能 例如：兌換外幣、轉帳等等。

# %%
money = {'Tom' : {
                "NT":30000}, 
         'Mary' : {"NT":64000},
         'Gary' : {"NT":72000}, 
         'Tim' : {"NT":500},
         'Eva' : {"NT":6150}}
def main():
    while True:        
        print('\n   *歡迎來到hoho提款機*')
        print('\n')
        print('*********************************')
        print('*   創建新客戶與金錢           ---請按 1  *')
        print('*   查詢客戶的存款金額         ---請按 2  *')
        print('*   存款與提款(可提存不同外幣)  ---請按 3  *')
        print('*   轉帳(可外幣)               ---請按  4  *')
        print('*   列出目前客戶名單與金額      ---請按  5  *')
        print('*   退出hoho提款機             ---請按 0  *')
        print('*********************************\n')
        v=input('您想做的服務是?')
        if  5<int(v) or int(v)<0:
            print('\n請重新輸入想做的服務！\n')
            continue
        else:
            v=int(v)
        if v==1:
            time=1
            while time==1:
                craetpersonmoney={}
                Name=input('請輸入姓名')
                personmoney=int(input(Name+"帳戶的金額是多少?"))
                country=input("要存入的幣值是(例如:台幣打NT)")
                updatemoney={country:personmoney}
                craetpersonmoney.update(updatemoney)
                craetpersonmoney={Name:updatemoney}
                money.update(craetpersonmoney)
                print("\n 下列為現有客戶資料",money)
                creat=int(input("是否要繼續新增客戶金額 繼續請按1 離開請按0\n"))
                if creat==0:
                    break
                else:
                    time=1
        elif v==2:
            time=1
            while time==1:
                while True:
                    Name=input('您想要查詢的姓名是?')
                    if Name in money:
                        print(Name+'當前的金額為：',money[Name])
                        break
                    else:
                        print('查無此人,重新輸入\n')
                        
                    
                creat=int(input("是否要繼續查詢客戶金額 繼續請按1 離開請按0\n"))
                if creat==0:
                    break
                else:
                    time=1
        elif v==3:
            time=1
            while time==1:
                while True:
                    Name=input('您想要提款\存款的姓名是?')
                    if Name in money:
                        country=input("要提款\存款的幣值是(例如:台幣打NT)")
                        putout=int(input("要提款\存款多少錢(例如:存款500提款-300)"))
                        if country in money[Name]:
                            personmoney=money[Name]
                            oldmoney=int(personmoney[country])
                            newoney=oldmoney+putout
                            if int(newoney)<0:
                                print("餘額不足,只有",oldmoney)
                                continue
                            else:
                                personmoney[country]=newoney   
                                print(Name+'先前的金額為：',oldmoney,'目前的金額為：',newoney)
                                break
                        else:
                            if int(putout)<0:
                                print("沒有這個貨幣!")
                                continue
                            else:
                                updatemoney={country:putout}
                                money[Name].update(updatemoney)
                                print(Name+"現有的錢",money[Name])
                                break
                    else:
                        print('查無此人,重新輸入\n')
                              
                creat=int(input("是否要繼續提款\存款金額 繼續請按1 離開請按0\n"))
                if creat==0:
                    break
                else:
                    time=1
        elif v==4:
            time=1
            while time==1:
                while True:
                    Name=input('您想要轉出的姓名是?')
                    if Name in money:
                        account=input('請輸入對方賬戶：')
                        if account in money:
                            country=input("要轉出的幣值是(例如:台幣打NT)")                            
                            if country in money[Name]:
                                putout=int(input("要轉出多少錢(例如:轉出500)"))
                                personmoney=money[Name]
                                oldmoney=int(personmoney[country])
                                newoney=oldmoney-putout
                                if int(newoney)<0:
                                    print("餘額不足,只有",oldmoney)
                                    continue
                                else:
                                    if country in money[account]:
                                        otherpeople=money[account]
                                        oldother=int(otherpeople[country])
                                        newother=oldother+putout
                                        print(account+'先前的金額為：',money[account][country],'目前的金額為：',newother)
                                    else:
                                        updatemoney={country:putout}
                                        money[account].update(updatemoney) 
                                        print(account+'先前的金額為：0目前的金額為：',money[account][country])
                                    personmoney[country]=newoney  
                                    otherpeople[country]=newother
                                    print(Name+'先前的金額為：',oldmoney,'目前的金額為：',newoney)
                                    break
                                 
                            else:
                                print("沒有這個貨幣!")
                                continue
                                            
                        else:
                            print('查無此人,重新輸入\n')
                            continue
                    else:
                            print('查無此人,重新輸入\n')
                            continue

                              
                creat=int(input("是否要繼續轉帳 繼續請按1 離開請按0\n"))
                if creat==0:
                    break
                else:
                    time=1
            
            
        elif v==5:
            while True:
                print(money)
                creat=int(input("是否要離開 離開請按0\n"))
                if creat==0:
                    break   
                            
        elif v==0:
            print('已離開hoho提款機\n')
            break
            
print("下列為現有的客戶與金額",money)                
main()
# Out:
# 下列為現有的客戶與金額 {'Tom': {'NT': 30000}, 'Mary': {'NT': 64000}, 'Gary': {'NT': 72000}, 'Tim': {'NT': 500}, 'Eva': {'NT': 6150}}
#
#    *歡迎來到hoho提款機*
#
#
# *********************************
# *   創建新客戶與金錢           ---請按 1  *
# *   查詢客戶的存款金額         ---請按 2  *
# *   存款與提款(可提存不同外幣)  ---請按 3  *
# *   轉帳(可外幣)               ---請按  4  *
# *   列出目前客戶名單與金額      ---請按  5  *
# *   退出hoho提款機             ---請按 0  *
# *********************************
#
# 您想做的服務是?1
# 請輸入姓名KOKO
# KOKO帳戶的金額是多少?2000
# 要存入的幣值是(例如:台幣打NT)NT
#
#  下列為現有客戶資料 {'Tom': {'NT': 30000}, 'Mary': {'NT': 64000}, 'Gary': {'NT': 72000}, 'Tim': {'NT': 500}, 'Eva': {'NT': 6150}, 'KOKO': {'NT': 2000}}
# 是否要繼續新增客戶金額 繼續請按1 離開請按0
# 1
# 請輸入姓名MOMO
# MOMO帳戶的金額是多少?6000
# 要存入的幣值是(例如:台幣打NT)
#
#  下列為現有客戶資料 {'Tom': {'NT': 30000}, 'Mary': {'NT': 64000}, 'Gary': {'NT': 72000}, 'Tim': {'NT': 500}, 'Eva': {'NT': 6150}, 'KOKO': {'NT': 2000}, 'MOMO': {'': 6000}}
# 是否要繼續新增客戶金額 繼續請按1 離開請按0
# 0
#
#    *歡迎來到hoho提款機*
#
#
# *********************************
# ...
